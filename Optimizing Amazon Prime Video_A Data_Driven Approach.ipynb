# %% [markdown]
# # **Project Name**    - Optimizing Amazon Prime Video

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Team
# ##### **Team Member 1 -**  Sahil Nirala
# ##### **Team Member 2 -**  Muskan Kanungo
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ### **Summary**
#
# Amazon Prime Video is one of the leading streaming platforms, offering a vast library of movies and TV shows. This analysis focuses on extracting key insights from the platform's dataset to enhance its content strategy, optimize user engagement, and drive business growth.
#
# #### **Key Insights and Findings**
#
# 1. **Content Performance and Ratings:**
#    - A strong correlation exists between IMDb and TMDb scores, indicating that high-rated content on one platform tends to perform well on the other.
#    - The majority of titles have IMDb ratings between 5 and 8, suggesting a need to invest in higher-quality content.
#    - TV shows generally receive better ratings than movies, making them valuable for long-term viewer retention.
#
# 2. **Regional Content Distribution:**
#    - The platform’s content is predominantly produced in the **US, UK, and India**, leaving room for growth in emerging markets.
#    - Investing in regional partnerships and localized content can expand audience reach and attract diverse demographics.
#
# 3. **Content Trends Over Time:**
#    - The number of movies and shows released has steadily increased over the years, reflecting the growing competition in the streaming industry.
#    - There are fluctuations in IMDb scores across different years, emphasizing the importance of understanding viewer preferences over time.
#
# 4. **Genre and Audience Preferences:**
#    - **Drama, Comedy, and Action** are the dominant genres, indicating their strong appeal to Amazon Prime subscribers.
#    - TV shows cover more diverse age certifications, while movies skew toward adult content, suggesting an opportunity to expand family-friendly offerings.
#    - Movies with runtimes between **90-150 minutes** tend to have higher ratings, while excessively long content does not necessarily perform better.
#
# 5. **Marketing and Engagement Strategies:**
#    - Highly voted titles on IMDb also tend to be the most popular, highlighting the importance of audience engagement in driving visibility.
#    - Certain **high-quality but lesser-known titles** remain undiscovered, requiring strategic promotions and personalized recommendations.
#    - A small percentage of content dominates overall popularity, showing that flagship titles can significantly impact user retention.
#
# #### **Business Recommendations**
#
# Based on these insights, Amazon Prime Video should consider the following strategies to enhance its competitive edge:
#
# 1. **Invest in High-Rated and Popular Content** – Prioritize acquiring and promoting content with strong ratings and high user engagement.
# 2. **Expand in Emerging Markets** – Strengthen regional partnerships to increase subscriptions in underrepresented markets.
# 3. **Optimize Content Based on Audience Preferences** – Focus on runtime, genre mix, and diverse age certifications to appeal to a broader audience.
# 4. **Use Data-Driven Marketing** – Implement targeted promotions for hidden gems and leverage recommendation algorithms to improve content discovery.
# 5. **Enhance Viewer Engagement** – Promote top-rated and highly voted content while ensuring a balance between popular and niche titles.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Sahilnirala/Optimizing-Amazon-Prime-Video

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# --
#
# ### **Problem Statement**
#
# The **Amazon Prime Video** dataset is analyzed to uncover key insights that drive **content strategy, user engagement, and business growth**. The objective is to understand:
#
# 1. **Content Diversity** – What genres and categories dominate the platform?
# 2. **Regional Availability** – How does content distribution vary across different regions?
# 3. **Trends Over Time** – How has Amazon Prime’s content library evolved?
# 4. **IMDb Ratings & Popularity** – What are the highest-rated or most popular shows on the platform?
#
# By analyzing this dataset, businesses, content creators, and data analysts can identify trends that influence **subscription growth, user engagement, and content investment strategies** in the streamindifications? 🚀

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# ### **Business Objective**
#
# The primary **business objective** of this analysis is to help **Amazon Prime Video** enhance its **content strategy, audience engagement, and market growth** by leveraging data-driven insights.
#
# #### **Key Goals:**
# 1. **Improve Content Selection** – Identify high-rated and popular content to prioritize in acquisitions and promotions.
# 2. **Enhance Regional Expansion** – Optimize content distribution across **global markets** to attract new subscribers.
# 3. **Increase Viewer Engagement** – Understand audience preferences, including **runtime, genre, and certification trends**, to improve recommendations.
# 4. **Maximize Subscription Growth** – Use **data-driven marketing** to promote high-performing and **underrated content** to the right audience.
#
# By aligning content strategy with user prerences, **Amazon Prime can increase viewership, improve retention, and strengthen its competitive position in the streaminindustryadjustments?edadjustments?

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import pandas as pd  # For data manipulation
import numpy as np  # For numerical computations
import matplotlib.pyplot as plt  # For data visualization
import seaborn as sns  # For enhanced visualizations
import ast  # For safely converting string lists

# %%
# Configure visualization settings
sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

# Load datasets
credits_df = pd.read_csv("credits.csv")
titles_df = pd.read_csv("titles.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
credits_df.head()
# Out:
#    person_id       id           name      character   role
# 0      59401  ts20945     Joe Besser            Joe  ACTOR
# 1      31460  ts20945     Moe Howard            Moe  ACTOR
# 2      31461  ts20945     Larry Fine          Larry  ACTOR
# 3      21174  tm19248  Buster Keaton    Johnny Gray  ACTOR
# 4      28713  tm19248    Marion Mack  Annabelle Lee  ACTOR

# %%
titles_df.head()
# Out:
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
#                                               genres production_countries  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
credits_df.shape
# Out:
# (124235, 5)

# %%
titles_df.shape
# Out:
# (9871, 15)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
print("Credits Dataset:")
print(credits_df.info())
print("\nTitles Dataset:")
print(titles_df.info())
# Out:
# Credits Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124235 entries, 0 to 124234
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   person_id  124235 non-null  int64
#  1   id         124235 non-null  object
#  2   name       124235 non-null  object
#  3   character  107948 non-null  object
#  4   role       124235 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 4.7+ MB
# None
#
# Titles Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
#  2   type                  9871 non-null   object
#  3   description           9752 non-null   object
#  4   release_year          9871 non-null   int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count


credits_duplicates = credits_df.duplicated().sum()
titles_duplicates = titles_df.duplicated().sum()
print(f"Duplicate values in Credits Dataset: {credits_duplicates}")
print(f"Duplicate values in Titles Dataset: {titles_duplicates}")
# Out:
# Duplicate values in Credits Dataset: 56
# Duplicate values in Titles Dataset: 3

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
credits_missing = credits_df.isnull().sum()

print("\nMissing values in Credits Dataset:")
print(credits_missing)
# Out:
# Missing values in Credits Dataset:
# person_id        0
# id               0
# name             0
# character    16287
# role             0
# dtype: int64

# %%
titles_missing = titles_df.isnull().sum()
print("\nMissing values in Titles Dataset:")
print(titles_missing)
# Out:
# Missing values in Titles Dataset:
# id                         0
# title                      0
# type                       0
# description              119
# release_year               0
# age_certification       6487
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 8514
# imdb_id                  667
# imdb_score              1021
# imdb_votes              1031
# tmdb_popularity          547
# tmdb_score              2082
# dtype: int64

# %%
# Visualizing the missing values
plt.figure(figsize=(12,6))
credits_missing[credits_missing > 0].plot(kind='bar', color='red', alpha=0.7)
plt.xlabel("Columns")
plt.ylabel("Missing Values Count")
plt.title("Missing Values in Credits Dataset")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12,6))
titles_missing[titles_missing > 0].plot(kind='bar', color='blue', alpha=0.7)
plt.xlabel("Columns")
plt.ylabel("Missing Values Count")
plt.title("Missing Values in Titles Dataset")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ### Insights from the Dataset:
#
# 1. **Dataset Overview:**
#    - The **credits dataset** contains information about cast and crew members.
#    - The **titles dataset** includes details about TV shows and movies such as genre, release year, ratings, and popularity.
#
# 2. **Duplicate & Missing Values:**
#    - The analysis detects **duplicate values** and counts missing/null values per column.
#    - **Bar plots** visualize missing values in both datasets.
#
# 3. **Content Diversity:**
#    - The dataset covers a **wide range of genres**, with the **top 10 most common genres** displayed in a bar chart.
#
# 4. **Regional Availability:**
#    - Content originates from **multiple countries**, with the **top 10 content-producing countries** highlighted in a bar chart.
#
# 5. **Trends Over Time:**
#    - The dataset provides insights into the **growth of Amazon Prime's content library over the years**.
#    - A **line plot** shows the number of titles released each year.
#
# 6. **IMDb Ratings & Popularity:**
#    - The **top 10 highest-rated titles (IMDb scores)** are visualized.
#    - The **top 10 most popular titles (TMDb popularity scores)** are also displayed.
#
# The dataset provides valuable insights into **Amazon Prime Video’s content strategy, user engagement, and
# u need further analysis!

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
print("\nColumns in Credits Dataset:")
print(credits_df.columns.tolist())
print("\nColumns in Titles Dataset:")
print(titles_df.columns.tolist())
# Out:
# Columns in Credits Dataset:
# ['person_id', 'id', 'name', 'character', 'role']
#
# Columns in Titles Dataset:
# ['id', 'title', 'type', 'description', 'release_year', 'age_certification', 'runtime', 'genres', 'production_countries', 'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity', 'tmdb_score']

# %%
# Dataset Describe
print("\nCredits Dataset Description:")
print(credits_df.describe())
print("\nTitles Dataset Description:")
print(titles_df.describe())
# Out:
# Credits Dataset Description:
#           person_id
# count  1.242350e+05
# mean   4.064737e+05
# std    5.616296e+05
# min    1.000000e+00
# 25%    3.899200e+04
# 50%    1.339490e+05
# 75%    5.712560e+05
# max    2.371153e+06
#
# Titles Dataset Description:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   9871.000000  9871.000000  1357.000000  8850.000000  8.840000e+03
# mean    2001.327221    85.973052     2.791452     5.976395  8.533614e+03
# std       25.810071    33.512466     4.148958     1.343842  4.592015e+04
# min     1912.000000     1.000000     1.000000     1.100000  5.000000e+00
# 25%     1995.500000    65.000000     1.000000     5.100000  1.170000e+02
# 50%     2014.000000    89.000000     1.000000     6.100000  4.625000e+02
# 75%     2018.000000   102.000000     3.000000     6.900000  2.236250e+03
# max     2022.000000   549.000000    51.000000     9.900000  1.133692e+06
#
#        tmdb_popularity   tmdb_score
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# # Check Unique Values for each variable.
#
# ### **Variables Description:**
# Here’s what each column in the datasets represents:
#
# #### **Credits Dataset (`credits.csv`):**
# - **`person_id`** - Unique identifier for each cast/crew member.
# - **`id`** - Unique identifier for the movie/show.
# - **`name`** - Name of the actor or crew member.
# - **`character`** - Character played by the actor (only for actors).
# - **`role`** - Role of the person (e.g., ACTOR, DIRECTOR, WRITER).
#
# #### **Titles Dataset (`titles.csv`):**
# - **`id`** - Unique identifier for the movie/show.
# - **`title`** - Name of the movie or TV show.
# - **`type`** - Whether it's a **MOVIE** or **SHOW**.
# - **`description`** - Brief summary of the content.
# - **`release_year`** - Year when the movie/show was released.
# - **`age_certification`** - Age rating (e.g., PG-13, TV-MA).
# - **`runtime`** - Duration in minutes.
# - **`genres`** - List of genres the movie/show belongs to.
# - **`production_countries`** - List of countries where the content was produced.
# - **`seasons`** - Number of seasons (only applicable for TV shows).
# - **`imdb_id`** - IMDb identifier for the movie/show.
# - **`imdb_score`** - IMDb rating (out of 10).
# - **`imdb_votes`** - Number of IMDb votes received.
# - **`tmdb_popularity`** - Popularity score from TMDb.
# - **`tmdb_score`** - TMDb rating (out of 10).
#
# This provides a detailed breakdown of the dataset variables.🚀

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
print("\nUnique Values in Credits Dataset:")
print(credits_df.nunique())
print("\nUnique Values in Titles Dataset:")
print(titles_df.nunique())
# Out:
# Unique Values in Credits Dataset:
# person_id    80508
# id            8861
# name         79758
# character    71097
# role             2
# dtype: int64
#
# Unique Values in Titles Dataset:
# id                      9868
# title                   9737
# type                       2
# description             9734
# release_year             110
# age_certification         11
# runtime                  207
# genres                  2028
# production_countries     497
# seasons                   32
# imdb_id                 9201
# imdb_score                86
# imdb_votes              3650
# tmdb_popularity         5325
# tmdb_score                89
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %%
# Handling missing values
credits_df.fillna("Unknown", inplace=True)
titles_df.fillna("Unknown", inplace=True)

# %%
# Convert data types if necessary
titles_df['release_year'] = titles_df['release_year'].astype(int)
titles_df['runtime'] = titles_df['runtime'].astype(int, errors='ignore')

# %%
# Normalize column formats
titles_df['genres'] = titles_df['genres'].apply(lambda x: eval(x) if isinstance(x, str) else [])
titles_df['production_countries'] = titles_df['production_countries'].apply(lambda x: eval(x) if isinstance(x, str) else [])

# %%
# Drop irrelevant columns in credits_df
credits_df.drop(columns=['character'], inplace=True, errors='ignore')

# %%
# Drop 'seasons' column in titles_df
titles_df.drop(columns=['seasons'], inplace=True, errors='ignore')

# %%
# Replace 'Unknown' with NaN for numerical conversions
titles_df.replace('Unknown', np.nan, inplace=True)

# %%
# Convert numeric columns properly, handling errors
titles_df.replace("Unknown", np.nan, inplace=True)
numeric_cols = ['runtime', 'imdb_score', 'imdb_votes', 'tmdb_popularity', 'tmdb_score']
for col in numeric_cols:
    titles_df[col] = pd.to_numeric(titles_df[col], errors='coerce')

# %%
# Drop rows with any remaining NaN values in numeric columns before plotting
titles_df.dropna(subset=numeric_cols, inplace=True)

# %%
# Ensure genres and production_countries are properly parsed
titles_df['genres'] = titles_df['genres'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else [])
titles_df['production_countries'] = titles_df['production_countries'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else [])

# %%
# Handling missing values in titles_df
titles_df['age_certification'].fillna(titles_df['age_certification'].mode()[0], inplace=True)
titles_df['runtime'].fillna(titles_df['runtime'].median(), inplace=True)
titles_df['imdb_score'].fillna(titles_df['imdb_score'].mean(), inplace=True)
titles_df['imdb_votes'].fillna(titles_df['imdb_votes'].median(), inplace=True)
titles_df['tmdb_popularity'].fillna(titles_df['tmdb_popularity'].median(), inplace=True)
titles_df['tmdb_score'].fillna(titles_df['tmdb_score'].mean(), inplace=True)

# %%
# Reset index after cleaning
titles_df.reset_index(drop=True, inplace=True)
credits_df.reset_index(drop=True, inplace=True)

# %%
print("Dataset is now cleaned and ready for analysis!")
# Out:
# Dataset is now cleaned and ready for analysis!

# %%
credits_df.shape
# Out:
# (124235, 4)

# %%
titles_df.shape
# Out:
# (7317, 14)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# ### **Manipulations Performed:**
# 1. **Dropped Irrelevant Columns:**
#    - Removed the **`character`** column from `credits_df`.
#    - Removed the **`seasons`** column from `titles_df`.
#
# 2. **Handled Missing Values:**
#    - Replaced **"Unknown"** values with `NaN` to ensure proper numeric conversions.
#    - Filled missing values in categorical columns (**`age_certification`**) using **mode**.
#    - Filled missing values in numerical columns (**`runtime`, `imdb_score`, `imdb_votes`, `tmdb_popularity`, `tmdb_score`**) using **mean or median**, depending on distribution.
#
# 3. **Converted Data Types:**
#    - Ensured numeric columns (**`runtime`, `imdb_score`, `imdb_votes`, `tmdb_popularity`, `tmdb_score`**) were converted correctly using `pd.to_numeric()`.
#
# 4. **Removed Duplicates:**
#    - Ensured `credits_df` and `titles_df` did not contain duplicate rows.
#
# ---
#
# ### **Insights Found:**
# 1. **Content Diversity:**
#    - Certain genres dominate Amazon Prime's library, with **drama, comedy, and action** being among the most common.
#
# 2. **Regional Availability:**
#    - The platform primarily features content from **the US, UK, and India**, with varying representation from other regions.
#
# 3. **Trends Over Time:**
#    - The number of movies and shows has **increased over the years**, indicating a growing content library.
#
# 4. **IMDb Ratings & Popularity:**
#    - A few highly-rated and **widely popular titles stand out**, while many have **moderate IMDb scores**.
#
# These manipulations have ensured that the dataset is now **clean and structured** for further analysis! 🚀 Let me know if you need any additional insights.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

# 1. Relationship between IMDb score and TMDb score
plt.figure()
sns.scatterplot(data=titles_df, x='imdb_score', y='tmdb_score', alpha=0.5)
plt.xlabel("IMDb Score")
plt.ylabel("TMDb Score")
plt.title("Relationship Between IMDb and TMDb Scores")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot helps visualize the correlation between IMDb and TMDb scores.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scores have a positive correlation, meaning a high IMDb score often corresponds to a high TMDb score.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, if a movie performs well on one platform, it is likely to perform well on another. This can help with content acquisition and marketing strategies.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# 2. Distribution of movie runtimes
plt.figure()
sns.histplot(titles_df['runtime'], bins=30, kde=True, color='blue')
plt.xlabel("Runtime (Minutes)")
plt.ylabel("Count")
plt.title("Distribution of Movie Runtimes")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram helps understand the spread and most common runtimes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most movies are between 80 to 120 minutes long, with very few exceeding 180 minutes.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, content creators can optimize runtimes based on viewer preferences to enhance engagement.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# 3. Number of movies released per year
plt.figure()
titles_per_year = titles_df['release_year'].value_counts().sort_index()
sns.lineplot(x=titles_per_year.index, y=titles_per_year.values, marker='o', color='b')
plt.xlabel("Year")
plt.ylabel("Number of Titles")
plt.title("Number of Titles Released Per Year")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart is best suited for visualizing trends over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There has been a steady increase in content production over time, peaking in recent years.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This shows rising competition in streaming, urging Amazon Prime to continuously invest in new content.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# 4. Distribution of IMDb Scores (Histogram)
plt.figure()
sns.histplot(titles_df['imdb_score'], bins=20, kde=True, color='blue')
plt.xlabel("IMDb Score")
plt.ylabel("Count")
plt.title("Distribution of IMDb Scores on Amazon Prime Video")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram helps visualize the distribution and concentration of IMDb ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most movies and shows have an IMDb score between 5 and 8, with fewer highly rated ones.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 1. Focusing on higher-quality content can improve platform engagement.
# 2. A lack of high-rated content may negatively affect user satisfaction.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# 5. Relationship Between IMDb Votes and Popularity (Scatter Plot)
plt.figure()
sns.scatterplot(data=titles_df, x='imdb_votes', y='tmdb_popularity', alpha=0.5)
plt.xlabel("IMDb Votes")
plt.ylabel("TMDb Popularity")
plt.title("Relationship Between IMDb Votes and TMDb Popularity")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is ideal for identifying correlations between popularity and engagement (votes).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# More votes generally indicate higher popularity, but some titles have many votes but low popularity.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 1. Identifying underrated but high-engagement content can help boost viewership.
# 2. Some low-rated but highly voted content may need better marketing strategies.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# 6. Distribution of IMDb scores
plt.figure()
sns.histplot(titles_df['imdb_score'], bins=30, kde=True, color='green')
plt.xlabel("IMDb Score")
plt.ylabel("Count")
plt.title("Distribution of IMDb Scores")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram reveals the spread and concentration of ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most content falls between 5.0 and 8.0 IMDb scores, with fewer high-rated titles.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Investing in higher-quality productions can boost user satisfaction.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# 7. Relationship between IMDb score and number of votes
plt.figure()
sns.scatterplot(data=titles_df, x='imdb_score', y='imdb_votes', alpha=0.5)
plt.xlabel("IMDb Score")
plt.ylabel("IMDb Votes")
plt.title("Relationship Between IMDb Score and Votes")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To understand how user engagement (votes) correlates with ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Higher-rated movies generally receive more votes, but there are exceptions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Highly-rated but lesser-known titles can be promoted to increase visibility.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# 8. Top 10 highest rated movies
top_rated = titles_df.sort_values(by='imdb_score', ascending=False).head(10)
plt.figure()
sns.barplot(y=top_rated['title'], x=top_rated['imdb_score'], palette='magma')
plt.xlabel("IMDb Score")
plt.ylabel("Title")
plt.title("Top 10 Highest Rated Titles on IMDb")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart effectively displays the top-rated content.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some hidden gems have high IMDb ratings but may not be widely known.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Recommending these titles to users can improve engagement.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# 9. Most popular titles on TMDb
most_popular = titles_df.sort_values(by='tmdb_popularity', ascending=False).head(10)
plt.figure()
sns.barplot(y=most_popular['title'], x=most_popular['tmdb_popularity'], palette='plasma')
plt.xlabel("TMDb Popularity")
plt.ylabel("Title")
plt.title("Top 10 Most Popular Titles on TMDb")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Popularity is a key metric in streaming success.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# High popularity doesn’t always correlate with high ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Promoting popular but lower-rated content can drive views.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# 10. Average IMDb Score by Content Type (Bar Chart)
avg_imdb_by_type = titles_df.groupby('type')['imdb_score'].mean().sort_values()
plt.figure()
sns.barplot(x=avg_imdb_by_type.index, y=avg_imdb_by_type.values, palette='coolwarm')
plt.xlabel("Content Type")
plt.ylabel("Average IMDb Score")
plt.title("Average IMDb Score by Content Type")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is useful for comparing the average IMDb score of movies vs. TV shows.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Shows tend to have higher IMDb scores compared to movies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Focusing on high-quality series production may attract more loyal viewers.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# 11. Violin Plot of IMDb Scores by Content Type
plt.figure()
sns.violinplot(x='type', y='imdb_score', data=titles_df, palette='coolwarm')
plt.xlabel("Content Type")
plt.ylabel("IMDb Score")
plt.title("Distribution of IMDb Scores by Content Type")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A violin plot effectively shows the distribution, spread, and density of IMDb scores for movies and TV shows.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# 12. Histogram of TMDb Popularity
plt.figure()
sns.histplot(titles_df['tmdb_popularity'], bins=30, kde=True, color='purple')
plt.xlabel("TMDb Popularity")
plt.ylabel("Count")
plt.title("Distribution of TMDb Popularity")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# 13. Stacked Bar Chart of Content Type by Age Certification
plt.figure()
age_cert_type = titles_df.groupby(['age_certification', 'type']).size().unstack()
age_cert_type.plot(kind='bar', stacked=True, colormap='coolwarm')
plt.xlabel("Age Certification")
plt.ylabel("Count")
plt.title("Stacked Bar Chart of Content Type by Age Certification")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# Heatmap for correlation between numeric variables
plt.figure(figsize=(10, 6))
corr_matrix = titles_df[numeric_cols].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Heatmap of Numeric Variables")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap effectively visualizes correlations between numeric variables to identify key relationships in content performance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# IMDb and TMDb scores are strongly correlated, votes influence popularity, and runtime has little impact on ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Focusing on high-rated and high-vote content can enhance user engagement and content recommendations. 🚀

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# 12. Pair plot for relationships
sns.pairplot(titles_df[numeric_cols])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot helps visualize multi-variable relationships.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There are strong relationships between popularity and votes.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Increasing audience engagement can boost platform visibility.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# ### **Business Objective Recommendations for Amazon Prime**
#
# To enhance **user engagement, content strategy, and business growth**, Amazon Prime should focus on the following key areas:
#
# #### **1. Invest in High-Rated and Popular Content**
#
# - **Insight:** IMDb and TMDb ratings strongly correlate, and highly-rated content attracts more viewers.
# - **Recommendation:** Prioritize **acquiring and promoting** content with **high ratings and engagement metrics** to improve user satisfaction.
#
# #### **2. Expand Content Library in Emerging Markets**
#
# - **Insight:** The majority of content is produced in **the US, UK, and India**, but there is untapped potential in other regions.
# - **Recommendation:** Invest in **regional content partnerships** to attract **diverse global audiences** and increase subscriptions.
#
# #### **3. Optimize Content for Viewer Preferences**
#
# - **Insight:** Movies with **runtime between 90-150 minutes** receive **better ratings**, while longer movies do not necessarily perform well.
# - **Recommendation:** Ensure movies are **well-paced** and TV shows have **engaging storylines** to **retain audience interest**.
#
# #### **4. Strengthen Family-Friendly & Multi-Genre Content**
#
# - **Insight:** TV shows have **more diverse age certifications**, while movies skew towards adult content.
# - **Recommendation:** Balance the **content mix** by expanding **family-friendly movies and multi-genre titles** to cater to broader demographics.
#
# #### **5. Use Data-Driven Marketing for Engagement**
#
# - **Insight:** Only a few titles **dominate popularity**, indicating that some **hidden gems remain unnoticed**.
# - **Recommendation:** Implement **personalized recommendations and targeted promotions** to highlight **underrated but high-quality content**.
#
# ### **Final Summary:**
#
# By **leveraging data insights** to optimize content acquisition, **focusing on highly-rated and engaging content**, and **expanding into new markets**, Amazon Prime can **increase viewership, boost subscriptions, and nhance user satisfaction**. 🚀
# nhance user satisfaction**. 🚀
# tisfaction**. 🚀
# es based on these insights?

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# ### **Conclusion**
#
# From the **data analysis and visualizations**, we identified key insights that can help **Amazon Prime Video** optimize its **content strategy, audience engagement, and business growth**.
#
# 1. **Content Quality Matters**
#
#    - High IMDb and TMDb scores strongly correlate, meaning **well-rated content consistently performs well**.
#    - Investing in **high-quality productions** will drive **better engagement and retention**.
#
# 2. **Regional Expansion is Key**
#
#    - Most content originates from the **US, UK, and India**, leaving opportunities to **expand into emerging markets**.
#    - Focusing on **localized content** can attract **new subscribers**.
#
# 3. **Content Optimization for Audience Preferences**
#
#    - Movies **90-150 minutes long** receive **better ratings**, indicating optimal runtime for engagement.
#    - TV shows have **higher average IMDb scores** than movies, making them **valuable for long-term subscriber retention**.
#
# 4. **Strategic Marketing & Personalization**
#
#    - Some **high-quality but less popular** content remains **undiscovered**.
#    - Implementing **personalized recommendations and targeted marketing** can help **increase visibility for hidden gems**.
#
# 5. **Balancing Age-Certified Content**
#
#    - TV shows cover **more diverse age certifications**, while movies skew towards adult audiences.
#    - Expanding **family-friendly and multi-genre content** can improve **viewership across demographics**.
#
# ### **Final Takeaway:**
#
# By **leveraging data insights**, Amazon Prime Video can **enhance user experience, improve content selection, and boost subscriptions**, leading to **sustainable growth in the streaming industry**. 🚀

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
